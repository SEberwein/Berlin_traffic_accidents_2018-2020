# %%
import pandas as pd
import numpy as np

# %%
data_first = pd.read_csv("./data/cleaned_data.csv")

# %%
data_first
# Out:
#        ujahr  umonat weekday  uwochentag       long        lat time_of_day  \
# 0       2018       1     Wed           4  52.513597  13.475018   afternoon
# 1       2018       1     Mon           2  52.587259  13.291022     morning
# 2       2018       1     Tue           3  52.526019  13.420578     morning
# 3       2018       1     Mon           2  52.481844  13.348288   afternoon
# 4       2018       1     Wed           4  52.583472  13.403228   afternoon
# ...      ...     ...     ...         ...        ...        ...         ...
# 38846   2020      12     Wed           4  52.466442  13.377941     morning
# 38847   2020      12     Tue           3  52.613018  13.310915   afternoon
# 38848   2020      12     Tue           3  52.506091  13.419649   afternoon
# 38849   2020      12     Tue           3  52.510570  13.391817   afternoon
# 38850   2020      12     Wed           4  52.559284  13.386714   afternoon
#
# ...

# %%
data_first["YYYYMM"] =
