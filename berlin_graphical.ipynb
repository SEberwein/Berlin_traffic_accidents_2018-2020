# %%
import mplleaflet
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# plz_shape_df = gpd.read_file('../Data/plz-gebiete.shp', dtype={'plz': str})

# plz_shape_df.head()

# %%
# import matplotlib.pyplot as plt
# from mpl_toolkits.basemap import pyproj
# from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15848/1892786212.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 from mpl_toolkits.basemap import pyproj
#       3 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
## <a href="https://www.freecountrymaps.com/map/towns/germany/240109189/">Map of Berlin</a>
im = plt.imread("./plots/berlin-map-germany-240109189.png")
implot = plt.imshow(im)
plt.show()
