# %%
import pandas as pd
import numpy as np

# %%
data_first = pd.read_csv("./data/monthly_incl_alc.csv")

# %%
data_first
# Out:
#       month  bicycle   car  pedestrian  motorbike  truck  other  \
# 0   2018_01      245   758         247         50     28    129
# 1   2018_02      201   640         153         39     30    101
# 2   2018_03      222   700         154         65     27    110
# 3   2018_04      453  1008         148        214     38    168
# 4   2018_05      679  1174         190        257     62    184
# 5   2018_06      647  1153         177        289     46    183
# 6   2018_07      547   987         125        241     41    162
# 7   2018_08      553  1017         135        274     32    179
# 8   2018_09      572  1027         150        292     42    148
# 9   2018_10      448  1037         176        225     42    177
# 10  2018_11      376   874         172        127     32    155
# 11  2018_12      249   780         236         81     23    120
# 12  2019_01      215   798         236         55     29    113
# 13  2019_02      231   680         145         67     31    106
# ...
